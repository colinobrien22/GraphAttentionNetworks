# %% [markdown]
# <a href="https://colab.research.google.com/github/colinobrien22/GraphAttentionNetworks/blob/main/notebooks/gat_cora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# If you get version conflicts, match torch & pyg versions explicitly.
# !pip -q install torch torch-geometric pyyaml pandas matplotlib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.2 MB/s eta 0:00:00

# %%
# Option A: clone repo
# !git clone https://github.com/colinobrien22/GraphAttentionNetworks.git
# %cd GraphAttentionNetworks
# !pip -q install -e .
# Out:
# Cloning into 'GraphAttentionNetworks'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 68 (delta 14), reused 64 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (68/68), 138.06 KiB | 1.77 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/GraphAttentionNetworks
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for graph-attention-networks (pyproject.toml) ... done

# %%
# !python -m graph_attention_networks.cli train --epochs 10
# Out:
# Config: {
#   "seed": 0,
#   "epochs": 10,
#   "hidden": 8,
#   "heads": 8,
#   "dropout": 0.6,
#   "lr": 0.005,
#   "weight_decay": 0.0005
# }
# Processing...
# Done!
# [001] loss=1.9446 | train=0.421 val=0.252 test=0.240
# [010] loss=1.8893 | train=0.900 val=0.770 test=0.793
# Best snapshot: {
#   "epoch": 9,
#   "val": 0.79,
#   "test": 0.8
# }

# %%
# !python -m graph_attention_networks.cli eval --model models/gat_cora.pt

import matplotlib.pyplot as plt
import pandas as pd

# Learning curve
df = pd.read_csv("results/metrics_epoch.csv")
plt.figure()
plt.plot(df["epoch"], df["acc_train"], label="train")
plt.plot(df["epoch"], df["acc_val"], label="val")
plt.plot(df["epoch"], df["acc_test"], label="test")
plt.legend(); plt.title("Accuracy vs Epoch"); plt.show()

# Confusion matrix
from IPython.display import Image, display
display(Image(filename="results/confusion_matrix.png"))
# Out:
# Evaluation: {
#   "test_acc": 0.8
# }
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2026868836.py in <cell line: 0>()
#       5
#       6 # Learning curve
# ----> 7 df = pd.read_csv("results/metrics_epoch.csv")
#       8 plt.figure()
#       9 plt.plot(df["epoch"], df["acc_train"], label="train")
#
# ...
